# %% [markdown]
# ### Disclaimer:
#
# This is based on the tutorial provided by:
# https://www.twilio.com/blog/build-whatsapp-bot-sentiment-analysis-python-twilio

# %% [markdown]
# ---
# # Chatter Trainer
# ---

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer
import pandas as pd

# %%
chatbot = ChatBot("Twily")
trainer = ListTrainer(chatbot)
# Out:
# [nltk_data] Downloading package stopwords to /home/lenovo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/lenovo/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# Training lists
#
# Our three types of arbitrary conversations are documentation_topics, twilio_knowledge and classifier.
#
# - documentation_topics:
#     - provides documentation links based on keywords found in the user's question
# - twilio_knowledge:
#     - will answer predefined general questions
# - classifier:
#     - has some keywords associated with a user frustration response, the bot will use these to try to de-escalate the user's frustration.

# %%
documentation_topics = [
("sdk", "https://www.twilio.com/docs/sms/whatsapp#sdks"),
("python helper library", "https://www.twilio.com/docs/libraries/python"),
("tutorials", "https://www.twilio.com/docs/sms/whatsapp/tutorial/ send-and-receive-media-messages-twilio-api-whatsapp"),
("autopilot", "https://www.twilio.com/docs/autopilot/channels/whatsapp"),
("contact us", "https://support.twilio.com/hc/en-us")]

# base knowledge
twilio_knowledge = [
("Twilio description", "Simply put, Twilio is a developer platform for communications.\
        Software teams use Twilio APIs to add capabilities like voice, video, and messaging \
        to their applications. This enables businesses to provide the right communications \
            experience for their customers."),
("Twilio email", "Sorry, you can submit a ticket at: https://www.twilio.com/console/support/tickets/create"),
("Twilio phone number", "We don't have a phone number for this type of account"),
("mailing address", "You can email our corporate headquarters at hello@craft.com"),
("chatterbot", "library making it easy to generate automated responses to a user's input, visit https://chatterbot.readthedocs.io/en/stable/"),
("textblob", "library for processing textual data, please visit https://textblob.readthedocs.io/en/dev/")
]

# sentiment
classifier = ["silly", "dumb", "stupid", "I'dont think so", "I don't care",
                   "do you know anything", "not good", "omg",
                   "this is bad", "not what I want", "live help",
                   "get me a rep", "I need a real person"]

# %% [markdown]
# ### Read Dataset
# - get the conversation from the `utterance` column
# - get the sentiments from `context` and `promt` columns

# %%
df_train = pd.read_csv("./dataset/train_arabic_updated.csv")
utterances = df_train["utterance"]
original_sentiments = df_train[["context","prompt"]].drop_duplicates()
# sentiments = list(zip(sentiments["context"], sentiments["prompt"]))

# %%
original_sentiments
# Out:
#             context                                             prompt
# 0       sentimental  I remember going to the fireworks with my best...
# 6            afraid                       i used to scare for darkness
# 12            proud  I showed a guy how to run a good bead in weldi...
# 17         faithful               I have always been loyal to my wife.
# 21        terrified  A recent job interview that I had made me feel...
# ...             ...                                                ...
# 78752     impressed  I was watching professional rodeo the other da...
# 78756  anticipating  I am waiting to see if I pass my graduate exam...
# 78760        afraid  My house burned down and I had to rescue my fa...
# 78764   sentimental  I found some pictures of my grandma in the att...
# 78769     surprised  I woke up this morning to my wife telling me s...
#
# [18090 rows x 2 columns]

# %%
map_empathy={
    "joy":["excited","proud","grateful","hopeful","confident","joyful","content","prepared","anticipating"],
    "love":["caring","sentimental","trusting","faithful","nostalgic"],
    "surprise":["impressed","surprised"],
    "sadness":["sad","lonely","guilty","disappointed","devastated","embarrassed","ashamed"],
    "anger":["angry","annoyed","furious","disgusted","jealous"],
    "afraid":["terrified","fear","anxious","apprehensive"]
}
map_empathy={
    "pos":["excited","proud","grateful","hopeful","confident","joyful","content","prepared","anticipating",
          "caring","sentimental","trusting","faithful","nostalgic","impressed","surprised"],
    
    "neg":["sad","lonely","guilty","disappointed","devastated","embarrassed","ashamed",
           "angry","annoyed","furious","disgusted","jealous","terrified","fear","anxious","apprehensive"],
}
data =[]
for reduced_empathy in map_empathy:
    for empathy in map_empathy[reduced_empathy]:
        data.append([reduced_empathy, empathy])
  
# Create the pandas DataFrame
df_map_empathy = pd.DataFrame(data, columns = ['empathy', 'context'])

# %%
df_map_empathy.head()
# Out:
#   empathy    context
# 0     pos    excited
# 1     pos      proud
# 2     pos   grateful
# 3     pos    hopeful
# 4     pos  confident

# %%
df_mapped_empathy = pd.merge(original_sentiments, df_map_empathy, how="inner" ,on='context' )
sentiments = list(zip(df_mapped_empathy["empathy"], df_mapped_empathy["prompt"]))

# %% [markdown]
# ### Training iterators
#
# Below the training list we will write three list iterators, each with a pre-formatted question/answer.
# Each loop calls the trainer instance and the train() method, passing the name of the list as an argument.
# This will generate conversations using the information found in each list.

# %%
trainer.train(utterances[:50])

for i in classifier:
    trainer.train([
        f"{i}",
        "I am sorry you feel that way, please ask the question again"
    ])
# Out:
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%

# %% [markdown]
# ### Corpus file export
#
# Finally we export our trainer instance to a JSON file using ChatterBot's .export_for_training() method, which takes an argument in the form of the JSON filename.

# %%
trainer.export_for_training('EnglishChatBot.json')

# %% [markdown]
# ---
# # Classifier
# ---

# %% [markdown]
# ### TextBlob
#
# "TextBlob provides a simple API for diving into common natural language processing (NLP) tasks such as part-of-speech tagging, noun phrase extraction, sentiment analysis, classification, translation, and more." ~ TextBlob documentation
#
#
# This application will mostly rely on TextBlob to create a custom classifier as well as do sentiment analysis and create our rule base chatbot.
#
#
# #### Textblob custom classifier
#
# In this section we will write our custom classifier, the other Textblob features will be explained as they are implemented throughout the tutorial.
#
# For this portion we need to create our train data. The data sets can be written in the script or imported from a file. TextBlob supports a few file formats for this operation, but we will write the data in our script.
#
# The data is a list of tuples, each housing the training string separated by a comma followed by "pos" or "neg", representing positive or negative sentiment.
#
# `[("phrase one", "pos"),
# ("phrase two", "neg")]`
#
#
#
# Let's write our classifier module. Begin by creating a python file named twily_classifier.py, in our twily folder
#
# We will create a function in order to import it into other scripts as a module.
#
#
#
# - We will import the Naive Bayers classifier from TextBlob.
# - Then we will create a function called trainer() which does not take any parameters at this point.
# - In it, we will assign our training data list to the train variable. The train data listed below is truncated to minimize the length of this tutorial.
# - Finally return NaiveBayesClassifier() constructor passing the train data as an argument.

# %%
from textblob.classifiers import NaiveBayesClassifier


def trainer(sentiment):
    """Trainer function for Naive Bayers classifier"""  
    return NaiveBayesClassifier(sentiment)

# %% [markdown]
# To test our classifier as a stand alone script, we will write test code below our trainer function.
#
# - We test our script by calling the trainer() function
# - And get the probability distribution by calling the .prob_classify() method and pass a test string we want analyzed as an argument.
# - We can extract the negative value by calling the .prob() method and passing the "neg" label as an argument.

# %%
sentiments
# Out:
# [('pos',
#   'I remember going to the fireworks with my best friend. There was a lot of people_comma_ but it only felt like us in the world.'),
#  ('pos',
#   'When I spend time with my father outside by the fire when we are camping.'),
#  ('pos',
#   "Every year on my kids birthday's I think back on when they were born. I remember all the sweet smells and sounds of them as a baby."),
#  ('pos',
#   'I came across an old keychain that my dad gave to me when I was younger. It was cool. '),
#  ('pos',
#   "I once went to see fireworks with my best friend. Best day of my life. We're no longer friends."),
#  ('pos',
#   "I'be been thinking a lot about my childhood lately_comma_ sort or reminiscing."),
#  ('pos',
#   'Went to the beach the other day and remember how much my friend liked going together.'),
#  ('pos',
#   'My husband and I went to dinner.  We were looking at photos of our kids when they were little.  It amazes me that one is already 18 and the other is just 2 short years away from being an adult also.'),
#  ('pos', 'I found my lugage broken and objects where stolen'),
#  ('pos',
#   'I felt this when my son turned one. It was such a special day and my husband and I spent hours going back and looking at all the photos from his first year.'),
#  ('pos',
#   'I was flying in to LAX and the Sierra Nevada Mountains below me made me feel like I was coming home.'),
#  ('pos',
#   'I was forced due to a family emergency to get rid of our family dog and move 550 miles away. It was one of the saddest moments in my life_comma_ in our lives... The dog was my first dog ever and my little buddy.  Tank loved me so much that when I drove off and looked in my rear view at him I cried like a baby. I cried as if my children were moving away from me. It was very sad.'),
#  ('pos',
#   "Realizing tonight how grown up our children are.  It won't be long before they are out of our house completely."),
#  ('pos', 'My niece is getting old enough to read the books I read as a kid.'),
#  ('pos',
#   'When I see homeless person_comma_ i feel tender feelings and become sentimental toward him'),
#  ('pos',
#   'Once_comma_ I had a big argument with my mom_comma_ but after awhile I realized I was wrong. So I tried to talk to her about it. '),
#  ('pos', 'Looking back on my childhood and how happy it was'),
#  ('pos', 'I have a pen that reminds me of my grandfather.'),
#  ('pos', 'I found an old picture of me and my dad yesterday.'),
#  ('pos',
#   'I stay up a lot and look at my kids baby photos. They were such fun babies.'),
#  ('pos',
#   'I love to reminisce about my youth with my daughter. She acts so much like me I know exactly what stories she would enjoy.'),
#  ('pos', 'The first time someone gave me flowers made me feel so special.'),
#  ('pos',
#   'I always get emotional when I think about my niece when she was born. It was one of the happiest moments in my life.'),
#  ('pos', 'Sometimes I just sit home and look at my kids baby pictures'),
#  ('pos',
#   'I found a ring I thought I had lost recently when I was cleaning out my closet. It had belonged to my grandfather and it was very special to me.'),
#  ('pos', 'I miss being a kid. Adulting is terrible'),
#  ('pos', 'when i came across an old diary '),
#  ('pos',
#   'My mom raised me and my brother by herself. I wish I could take care of her in her old age.'),
#  ('pos',
#   'The day that I found out that I was having a little girl really had me having all kinds of emotions. Having someone that would be a miniature me really had me in my feelings I went into the ultrasound room and it took about 15 minutes because she was not trying to cooperate that day but she finally calmed down and they were able to tell what she was and I got very teary eyed after finding out that information. '),
#  ('pos',
#   'I get sentimental when I see children and parents show affection with each other.'),
#  ('pos',
#   'I felt bad for a family member when they were going through hard times. I just made me care for them more'),
#  ('pos', "Finding my mother's picture."),
#  ('pos', 'I felt bad when my mom got sick. I had to take care of her'),
#  ('pos', 'I was happy when my brother got married. He deserved it'),
#  ('pos',
#   "Found someone's scarf the other day and returned it to her. She completely bawled."),
#  ('pos',
#   'There are times when I wish I could I had not sold my Nissan Maxima.  I have an SUV but I miss the sedan.  I miss driving closer to the ground and having better gas mileage.'),
#  ('pos', 'I miss my father so much.'),
#  ('pos',
#   'I get sentimental thinking about all the great times I had as a child on my street growing up'),
#  ('pos', '1'),
#  ('pos',
#   'I get sentimental about my family sometimes_comma_ I just really love them a lot'),
#  ('pos',
#   'i really like my brothers_comma_ they mean a lot to me even if it is frowned upon to express it'),
#  ('pos',
#   "There's a restaurant I go to often with my family. After all these years_comma_ they're closing down."),
#  ('pos', 'I love looking at my kids baby pictures. They were so sweet.'),
#  ('pos', 'I get sad when I think of my aunt. I wish she was still here'),
#  ('pos',
#   "I had an old pocket knife returned to me that's ~15 years old.  My cousin had it."),
#  ('pos', 'I miss my gramma so much'),
#  ('pos',
#   'I was watching old videos of my nieces and nephew when they were little. It really took me back.'),
#  ('pos',
#   "My grandmother is the prson that taught me how to cook. She is at the age now where she doesn't cook much anymore. Recently_comma_ she gave me all of her cookbooks and her apron."),
#  ('pos', 'when i found my dads old t shirt '),
#  ('pos',
#   'I get sentimental about my brothers_comma_ they are very important to me'),
#  ('pos',
#   'my son took his first steps yesterday_comma_ he is not a baby anymore. that made me cry'),
#  ('pos',
#   'I found some of my kids artwork from when they were little and it made me miss having them around all the time.'),
#  ('pos',
#   'My best friend called me up crying the other day. Her boyfriend is cheating on her.'),
#  ('pos', "My partner's mom passed away. I was very sad for her loss"),
#  ('pos',
#   'I found some pictures of when I was younger of myself with my friends'),
#  ('pos',
#   "When I see my mom post Facebook pics of her and my dad dining at restaurants I feel sad because my brother and I are usually part of their weekend restaurant excursions but we are both out of state doing our own thing...it's a mixed feeling of nostalgia_comma_ guilt_comma_ and fond memories"),
#  ('pos',
#   'I was going through some clutter in the attic this weekend and found a box of my old baseball stuff in it.  It brought back lots of good memories'),
#  ('pos',
#   'My best friend at work recently left the job to start her nursing career. I was so emotional.'),
#  ('pos', 'I miss my grandparents.'),
#  ('pos', 'I love finding pictures of my kids as babies!'),
#  ('pos',
#   "it's the anniversary of my grandmother's passing. It's been five years but I was there for her through the end."),
#  ('pos', 'I found some old toys from when I was a kid'),
#  ('pos', 'when i came across my parents old wedding rings'),
#  ('pos',
#   "I feel bad for parents who can't afford school clothes for their children."),
#  ('pos',
#   'I keep all of my kids elementary artwork. It is beginning to pile up.'),
#  ('pos', 'I was really touched to watch my daughter program'),
#  ('pos',
#   'Spaghetti always reminds me of my grandmother. She made the best spaghetti.'),
#  ('pos',
#   "I found my friend's senior ring that she left behind before going to college. I miss her."),
#  ('pos',
#   'I get sentimental about my family_comma_ they mean a lot to me and I do not know what I would do without them'),
#  ('pos',
#   'Whenever I look at old family pictures I get sentimental about the holidays we used to spend together.'),
#  ('pos',
#   'Found the gift my little brother gave to me_comma_ when he was 6 years old.'),
#  ('pos',
#   ' I get sentimental about my family_comma_ they mean a lot to me and I do not know what I would do without them'),
#  ('pos',
#   'I had such a nice time with my aunt going through my uncles things after he passed'),
#  ('pos',
#   'I miss when my toddlers were tiny little babies who couldnt even talk.'),
#  ('pos',
#   'My grandma died last month and now we have been sorting through her things. She has so many old family photo albums. We get distracted going through them.'),
#  ('pos', 'I still have my daughters first valentine that she gave me'),
#  ('pos', 'Got a gift from a friend from Brazil'),
#  ('pos',
#   "I found an old box with my baby's umbilical cord stump in it and it brought back memories."),
#  ('pos',
#   'I remember the last time I got to spend with my grandmother before she passed_comma_ how calm she was and how happy it made me.'),
#  ('pos',
#   'I remember when my mom would make Thanksgiving dinner.  It meant so much to me.'),
#  ('pos',
#   'Looking through my picture albums really makes me relive so many memories.'),
#  ('pos',
#   'I recently came across a toy in a thrift tore that looked similar to one that I had when I was a kid. It really made me remember my childhood.'),
#  ('pos', 'I was going through old photo albums.'),
#  ('pos', 'I saw my ex the other day.'),
#  ('pos', 'son preparing to leave for college'),
#  ('pos', 'My brother was working in my office'),
#  ('pos', "My friend's dog died "),
#  ('pos',
#   "Last summer my kids left for college. I got so emotional thinking about how short the time was since they were born. I didn't want to let go of them and was bawling."),
#  ('pos',
#   "As I attend all the graduations over the summer for family_comma_ I can't help to think back to my graduation."),
#  ('pos',
#   'I miss Sunday dinners at my grandmothers. We would have so much fun.'),
#  ('pos',
#   'I put up a bulletin board in my office just for my kids pictures. They brighten my day.'),
#  ('pos',
#   'I was just sitting here looking at old family photos.  A little sad.. but yet fun.'),
#  ('pos', 'I miss my ex. I sometimes look at our old pics on facebook.'),
#  ('pos', 'I got a box of my old toys from when I was a kid. '),
#  ('pos',
#   'I love getting together with my brother and reminiscing about when we were younger'),
#  ('pos',
#   "I logged in too facebook_comma_ I do not very often and felt a bit sad that I don't talk to anyone anymore. I have some really nice friends. I just don't feel like having people around anymore."),
#  ('pos', 'I saw a lady walking with her jack russell yesterday. I miss mine.'),
#  ('pos', 'I really miss the road trips I took as a kid.'),
#  ('pos',
#   "My grandma sent a lot of food to me through my mom. She's still making sure I get good food to eat."),
#  ('pos', "I inherited my grandfather's rifle. "),
#  ('pos',
#   'My son moved out last year. I still left his room how it was. Sometimes I go in there and look at his pictures and old trophies.'),
#  ('pos',
#   'I remember me and my sister being best friends as kids. We hardly ever speak now.'),
#  ('pos', 'I found the first Christmas ornament my daughter made. She was 3'),
#  ('pos', 'I went by my old school_comma_ and so much has changed.'),
#  ('pos',
#   "I saw firsthand today how caring my cousin can be with children. She was being patient and cooperative with my unruly and difficult two-year-old nephew_comma_ and she's only 13-years-old herself. I was pretty proud of how she handled the difficult situation_comma_ and it made me imagine her as a mother in the future."),
#  ('pos', 'I love seeing old friends'),
#  ('pos',
#   'Last year my grandfather passed away. I felt very nostalgic at that time.'),
#  ('pos',
#   'My dad gave me this gold chain way back when I was a kid. I wear it everyday since it means a lot to me.'),
#  ('pos',
#   'I think of old times when this movie comes on tv. It makes me think of when I was a kid'),
#  ('pos',
#   'I once collected rocks from a beach and I took them home to remember'),
#  ('pos', 'I was feeling nostalgic while packing away baby clothes earlier.'),
#  ('pos', 'i woke up from a dream missing my brother. i wish i could see him.'),
#  ('pos',
#   "The other day I was thinking how great it was to be a child. I didn't have to work or worry about paying bills. Life was so good back then."),
#  ('pos',
#   'I think most days now I get sentimental.  Our daughters are growing up and things strike me on a daily basis that life is changing.'),
#  ('pos',
#   'I found my old high school year book when I was cleaning.  It reminded me of some old times and it was a walk down memory lane'),
#  ('pos',
#   "My son is getting ready to start college this fall and it's really bringing back a lot of memories of my college days. "),
#  ('pos',
#   'I was helping my mom repain the house_comma_ and it reminded me of when I used to ask her if I can help her paint when I was little.'),
#  ('pos',
#   'I like to make my grandmothers old recipes on Sundays. IT reminds me of the time we had together'),
#  ('pos',
#   ' I was cleaning out a big closet today and found some Christmas ornaments of my kids feet when they were babies. So small and precious!'),
#  ('pos',
#   "There is a restaurant that has been around for a while. They're closing down after the wife passed away."),
#  ('pos',
#   'I same a photo of my deceased grandfather. It reminds me of when he was alive and he used to babysit me as a child. '),
#  ('pos',
#   'i get nostalgic when I hear this song. It makes me think of when I was a kid'),
#  ('pos', 'I keep everything my kids make. I am such a sao'),
#  ('pos',
#   'I went through all of my fb photos today. I was only looking at my kids photos. I miss them being babies.'),
#  ('pos',
#   "I'm taking care of my two nephews this weekend while their parents are out of town_comma_ and it's nice to see how the older one takes care of the younger one_comma_ despite them just being 7 and 2_comma_ respectively. It's awesome to see brothers caring for each other for a change_comma_ and it made me feel good about them."),
#  ('pos',
#   'I opened an old box of my grandfathers possessions that I was given after he passed away and found his watch that he always wore.  I became really nostalgic and thought of all the good times I had with him.'),
#  ('pos',
#   'I got high once I was home alone. I smoked a lot of weed and I was really paranoid'),
#  ('pos',
#   "I was looking at pictures of when I got engaged and can't believe how time has flown by_comma_ 14 years later."),
#  ('pos',
#   'When I was little my grandma gave me a little ceramic cat. I still keep it on display in my room because it reminds me of her.'),
#  ('pos',
#   'My father is giving me a watch that has been passed down for 3 generations.  It really means a lot to him so I am too.'),
#  ('pos',
#   'i was looking at pictures of my kids the other day and got a little sad '),
#  ('pos',
#   'Old pokemon games make me nostalgic and emotional for some odd reason_comma_ they were a big part of my childhood'),
#  ('pos', 'My keep my dads necklace close to me as much as possible.'),
#  ('pos', 'I drive my dads truck.'),
#  ('pos', 'Our dining room table is beat up but it belonged to my grandma.'),
#  ('pos', 'I am so happy to have my crazy family close.  '),
#  ('pos',
#   'I saw some old pics on FB of my dog who is passed and my niece. It was hard to see but they were good memories.'),
#  ('pos',
#   'I will never forget our last good fanily photo. We were all so happy then'),
#  ('pos', 'my cousin got shot in the head and i just could not stop crying '),
#  ('pos', 'I love seing the happy couples in the picture frames that I buy'),
#  ('pos',
#   'My dad gave me this gold necklace years and years ago. I really love it and I wear it every single day.'),
#  ('pos', 'I am very sensitive about the word fat'),
#  ('pos', 'Romance movies bring me back to my youthful days. '),
#  ('pos',
#   "I went to my brother's birthday party_comma_ and I was remembering the good old days."),
#  ('pos',
#   "This whole summer all me and my friends have done is get high and eat fast food. We got these McDonald's coins so I'm gonna keep one and remember this great summer."),
#  ('pos', 'I was going through some old childhood photos.'),
#  ('pos', 'Reading about the World Wars makes me feel so many emotions.'),
#  ('pos', 'when i came across an old letter from high school '),
#  ('pos',
#   'I get emotional about my brothers sometimes_comma_ they are so important to me'),
#  ('pos', 'I keep my kids on all my screensavers. They motivate me'),
#  ('pos', 'I keep a picture of my late great grandmother with me at all times'),
#  ('pos', 'i came across my old baby blanket'),
#  ('pos',
#   "I just celebrated my sons 14th birthday and can't believe he's growing up so fast.  How is a man in my house all of a sudden?"),
#  ('pos',
#   'I was spending time with family_comma_ and I started to feel happy about the time we have together.'),
#  ('pos',
#   'My brother recently sent me a scrapbook of a childhood pics and it made me happy.'),
#  ('pos',
#   'I still look at my kids baby photos. There were so sweet and innocent then'),
#  ('pos',
#   'I miss being a kid and just hanging out with my friends and cousin.Everyone is so busy now'),
#  ('pos', "I have had my father's wedding ring forever."),
#  ('pos',
#   'The only reason I have this house is because my parents bought it when it was affordable.'),
#  ('pos',
#   'I still have the food processor my mom gave me_comma_ when i went away for college.'),
#  ('pos',
#   "You know how FB will show you memories from years ago? It's showed me a few that made me think of my pets who have passed and how much I miss times with them."),
#  ('pos', 'I miss my dad. This was his favorite time of the year'),
#  ('pos',
#   "I still have every little craft mu kids have ever made. I can't throw them away."),
#  ('pos', 'when an old song came on that reminded me of my parents '),
#  ('pos',
#   'I get nostalgic when I work on my old truck in the garage sometimes.'),
#  ('pos',
#   'My former roomate left her cat keychain here. We fought a lot_comma_ but I kinda miss her now.'),
#  ('pos',
#   'Ive been looking through old photographs and thinking about all the people i am seeing in these pictures.  Makes me wonder what they are up to now'),
#  ('pos',
#   "When I see old pics of my late grandma I feel sad and kind of guilty I wasn't at her funeral."),
#  ('pos',
#   "My son's birthday is coming up and this even is making me feel this way."),
#  ('pos',
#   'I get emotional thinking about my brothers_comma_ they re really important to me'),
#  ('pos',
#   'My son will be turning two in a couple of months and I am feeling this way looking back.'),
#  ('pos', 'I wore the same dress my mother wore at my wedding'),
#  ('pos',
#   'My girlfriend gave me a box of chocolates the other day. I thought it was so sweet of her.'),
#  ('pos',
#   'i just went to a wedding this weekend_comma_ it was very emotional.'),
#  ('pos',
#   'Visited my mom last weekend and remember all the times we fought. We fought over such little things.'),
#  ('pos', 'This house is kinda empty without the kids.'),
#  ('pos', 'Now that I live alone_comma_ I miss having dinner with my parents.'),
#  ('pos', 'My mom dropped off food for me out of the blue.'),
#  ('pos',
#   'I saved the tickets to the first concert I ever went to. I still have them'),
#  ('pos',
#   'Days like today remind me of my childhood at the beach. We would go there every summer.'),
#  ('pos', 'when my uncle died'),
#  ('pos',
#   'I stare at my kids while they are alseep. Thats when they are on their best behavior'),
#  ('pos', 'When I was looking at baby pictures of my family.'),
#  ('pos',
#   'My dad gave me this gold necklace a while ago. I love it and wear it everyday.'),
#  ('pos',
#   'I keep every penny I find because I know my grandmother sent them from heaven.'),
#  ('pos',
#   'I just reconnected with a cousin of mine I used to hang out with when I was younger.'),
#  ('pos', 'I found it difficult to throw away my old cutlery collection.'),
#  ('pos', 'I am finding it difficult to sell my old car.'),
#  ('pos', 'Living in the house I grew up in means so much to me.'),
#  ('pos',
#   'I felt sentimental when I realized that next year would be my 25th year after graduation from high school.'),
#  ('pos',
#   'My grandmother passed away a long time ago. She left me her bible that helps me remind me of her.'),
#  ('pos',
#   'My dad passed away last year. He left me his watch that wear everyday. Its a nice memento.'),
#  ('pos',
#   'I saw a homeless man sleeping near Walmart when i came out after shopping. It was so sad to see him in such situation'),
#  ('pos',
#   "I would still take a bullet for my ex and her family.  Even though she blocked me on Facebook.  Call me a sucker but that girl was my first love and she gave me so much I wouldn't be here today if it wasn't for her"),
#  ('pos',
#   'My mother passed away a while back. I still use all of her favorite cooking pots when I cook. Its a great reminder.'),
#  ('pos', "i'm feeling mixed emotions about not having children"),
#  ('pos', 'I felt bad when I saw a stray dog. I almost had to stop'),
#  ('pos', 'I saw a picture of my mom. It made me miss her'),
#  ('pos', 'I saw some old pictures of back home. It made me miss it'),
#  ('pos',
#   'I feel something when I think back to where I came from. It makes me feel nostalgic'),
#  ('pos',
#   'I felt bad when I saw a homeless man on the side of the road. I wanted to help'),
#  ('pos', 'It makes me feel great to drive my old truck.'),
#  ('pos', 'I miss being a kid. I saw a show on tv that reminded me of that'),
#  ('pos', 'wataching an old tv show'),
#  ('pos',
#   'I have all of my kids first day pics in an album. I get emottional every first day of school'),
#  ('pos',
#   'I was looking at some pictures recently and got sentimental about my childhood.'),
#  ('pos',
#   'I was thinking about my pets a lot the past few days and how I will always be dedicated to helping animals.'),
#  ('pos',
#   'I miss when I was younger and living at home. It was such a innocent time. No worries about bills or anything like that.'),
#  ('pos', 'Tomorrow is my last day of work. I am going to miss my coworkers.'),
#  ('pos',
#   'Went through all my daughters ballet tshirts from the time she was 2 until now (15).  Reminded me of how little she was at one time.'),
#  ('pos',
#   'My girlfriend bought me a box of chocolates yesterday. It was so sweet of her!'),
#  ('pos', 'I found a box of old photos_comma_ brought back a lot of memories'),
#  ('pos', 'I love watching the movies I watched as a kid with my kids'),
#  ('pos', 'I really miss going to the park with my grandpa when I was little.'),
#  ('pos', 'I am finding it hard to sell my grandfathers cadillac '),
#  ('pos', 'I am finding it hard to let go of my old car.'),
#  ('pos',
#   'Yesterday I caught up talking with my cousin... it brought back so many good memories'),
#  ('pos',
#   "My daughter is starting high school next week.  I can't help but think back when she was first born on a day like today."),
#  ('pos', 'sometimes i miss the old days when there was no social media'),
#  ('pos',
#   'I moved away for a job last year. My friend gave me a painting right before I left. Every time I look at it it reminds of my friends.'),
#  ('pos',
#   'My neighbor just had a baby and thinking about a friend that recently passed away I had to go grab bagels to take to the hospital. She always did that when someone had a baby.'),
#  ('pos',
#   "I found my deceased grandfathers watch in an old box in my parents attic.  It is actually quite valuable_comma_ but I don't think I could bring myself to sell it.  It has way too much meaning to myself and my family."),
#  ('pos',
#   "My grandma passed away earlier this year. We used to always get together as a family and play cards on sundays. This sunday is the first time we're doing it again without her. It will feel weird_comma_ but nice to be with family again."),
#  ('pos',
#   "I need to upgrade my phone soon_comma_ but I have an attachment to it that I can't let go of."),
#  ('pos',
#   "I can't believe my favorite restaurant is closing. I am going to miss that place"),
#  ('pos',
#   'When my partner bought my a birthday present it made me very emotional.'),
#  ('pos', 'I always feel great when I think about old times.'),
#  ('pos',
#   "My dad gave me an old coin that used to belong to his grandfather.  I don't think it's worth much money_comma_ but it means a lot to me."),
#  ('pos',
#   "Tomorrow is my 14th year anniversary married to my wonderful husband.  I can't believe it was that long ago. What a wonderful day."),
#  ('pos',
#   "I remember when my kids were young and once fall came_comma_ we'd go to a pumpkin patch festival for a weekend.  Those were sweet days!"),
#  ('pos',
#   "I haven't been the greatest person_comma_ but my family always sticks by me."),
#  ('pos',
#   'I am feeling this way because my son is turning 2 in a couple of months.'),
#  ('pos', 'I wonder what my friend is doing now on the side of the world.'),
#  ('pos',
#   "My oldest daughter will graduate high school this year.  I'm having to pull old baby photos of her to put together the slide show for her homeschool graduation ceremony."),
#  ('pos',
#   'I was looking at pictures of my daughter when she was born... crazy how time flies'),
#  ('pos',
#   'My uncle passed away from heart attack. He was only 35 and he left behind a 3 year old daughter'),
#  ('pos',
#   "I spent time folding up all of my daughter's old dance shirts today.  Makes me remember when she first started dance at age 2_comma_ she'll turn 16 next month."),
#  ('pos', 'Everytime I see roses I think of my grandma.'),
#  ('pos',
#   'My sister is getting married next week. Though i am happy for her. I feel like am losing her and am going to miss her'),
#  ('pos',
#   'My dad gave me a necklace years and years ago. It meant a lot to me and I now wear it every day.'),
#  ('pos',
#   'last night i met my friend after a long time.its so sentimental and excited to meet her at the spot'),
#  ('pos', "I can't let go of my old car."),
#  ('pos',
#   'My dad bought me a necklace and put his 21st birthday charm on it. I wear it every single day now.'),
#  ('pos', "I miss my coworker. Her replacement just isn't the same."),
#  ('pos',
#   'When I was growing up_comma_ my brother had to raise me because my parents were so busy working. I felt terrible because he did everything he could and more to give me the best life I could have. And for a few years_comma_ I felt resent towards him for not doing more. But he put me through college and helped me so many times_comma_ I love him so much.'),
#  ('pos',
#   "I've got these shoes for over 5 years now. The sole is all worn out."),
#  ('pos', 'im happy that the kids will be returning to school next week!'),
#  ('pos',
#   ' i really love to look at old photo albums and see how everyone has grown and how things have changed'),
#  ('pos', 'I miss my dog this time of year.'),
#  ('pos',
#   'I get very nostalgic when I think about this time of year. Makes me think of when I was younger'),
#  ('pos', 'I miss being a kid with no responsibility'),
#  ('pos', 'My mom gave me a box of old toys I used when I was a kid.'),
#  ('pos',
#   'When my grandma passed away_comma_ I was given her jewelry which I wore on my wedding day. '),
#  ('pos',
#   "I saw a blue 1967 mustang drive by earlier and it reminded me of my dad's. He had it when I was a child."),
#  ('pos', 'My daughter is turning 2 next week. Times goes by too fast.'),
#  ('pos', "I found old family pictures... It's so bittersweet looking back"),
#  ('pos',
#   'I wish my mom had made a scrapbook of my childhood. I like passing down things'),
#  ('pos',
#   'I went to my college yesterday. It makes me nostalgic about my college days.'),
#  ('pos', 'I always feel weird when driving by my old high school'),
#  ('pos', 'I dont want to sell my old Cadillac.'),
#  ('pos',
#   'I went to the race track. We used to go there with my grandparents when we were kids. It made me think of them. '),
#  ('pos',
#   "My husband and I just celebrated out ninth wedding anniversary.  We've been through a lot of changes but we still love each other just as much."),
#  ('pos',
#   'I went to St. Augustine_comma_ where I had visited as a child. It made me think of my family trip there when I was younger. '),
#  ('pos',
#   'One of my friend shared a post of Syrian children being hit by bombs on Facebook. I feel so sad for those innocent children'),
#  ('pos', 'I get nostalgic thinking about my grandmother.'),
#  ('pos', 'I miss my mom and grandma'),
#  ('pos', 'I keep all of my pictures with my family.'),
#  ('pos',
#   'I was using a quilt the other day and it made me think of my great grandmother_comma_ because she made it for me.'),
#  ('pos',
#   'I had my first conversation with my two year old the other day.  He asked where the cat was_comma_ and wanted to go outside when I told him the cat was outside.'),
#  ('pos',
#   'I was looking through some old photo albums and it was so cool. It brought back a lot of memories. '),
#  ('pos', 'That scene in bambi_comma_ where the mother dies!'),
#  ('pos',
#   "I was looking at some of the old photos I have of my grandpa. He passed away_comma_ so I've been reminiscing over him."),
#  ('pos',
#   "I'm going off to college soon so I'll be moving away from the small city I grew up in. It's a bit tough because I loved living here."),
#  ('pos',
#   'I miss when I was young and my parents took me to the fair. I loved to go on the rides and eat candied apples. Those were the best times.'),
#  ('pos', 'The backyard makes me miss my dog.'),
#  ('pos', 'I miss my dog every time I see a dog.'),
#  ('pos',
#   "I was skipping rocks with my son the other day. That's something my grandfather used to do with me. It made me think back on the times I had with him."),
#  ('pos',
#   'Having this new baby puppy around reminds me of how fragile life is. I remember when my other animals who have passed were babies. Circle of life.'),
#  ('pos',
#   'I had an awesome dog as a kid. He was such a great dog and I miss him. '),
#  ('pos', 'This time of year always makes me reminisce.'),
#  ('pos', 'I hate to say this_comma_ but I miss school.'),
#  ('pos', 'I just watched the movie I saw with my wife on our first date.'),
#  ('pos',
#   'I was going through some old stuff in the attic the other day and found an old quilt from my grandma.  '),
#  ('pos',
#   "My dad and I were talking about the past_comma_ just reminiscing a bit.  His mind is going quickly_comma_ I know I won't have many more conversations with him like this."),
#  ('pos', 'I always look back at the days fb memories. They are so cool'),
#  ('pos',
#   'I lost my key chain which my grandma presented for my 10th birthday!!'),
#  ('pos', 'going through my childrens old clothes'),
#  ('pos',
#   "I found a old tool box with my grandfather's tools in it in the garage."),
#  ('pos',
#   'In inherited my grandfathers watch. I wear it when I feel like I need some extra luck.'),
#  ('pos', 'when i came across an old photo book from high school '),
#  ('pos',
#   'I inherited my fathers watch. I like to wear every now and then. Its a great reminder of him.'),
#  ('pos',
#   'I was going through a box with old papers in it and I found some old letter my Grandpa wrote me when I was a child. '),
#  ('pos', 'When I hear some songs I remember my time in high school'),
#  ('pos',
#   'I just found an old report card. It makes me miss elementary school before'),
#  ('pos',
#   'We found old pictures of grandparents while cleaning out my house.  It was crazy seeing them so young.'),
#  ('pos',
#   'I got a little sappy when I saw a puppy on facebook. It made me want a dog'),
#  ('pos',
#   'My mom dropped off some food for me out of the blue. I miss her cooking.'),
#  ('pos',
#   'i held on to my first Nintendo even though it doesnt work anymore. I just like how it reminds me of my childhood.'),
#  ('pos',
#   'My friend is going to across the country. I miss seeing her almost everyday.'),
#  ('pos',
#   "I miss my mom. Can't believe I used to be so annoyed seeing her everyday when I was little."),
#  ('pos',
#   "I've been feeling so down_comma_ I miss my family. I think it's time to go visit."),
#  ('pos',
#   "I've got a big tote of photos that need to be organized.  I was looking through them today and could only see how much my girls have grown."),
#  ('pos', 'When i see old people in roadside_comma_ i have tears in my eyes'),
#  ('pos',
#   'I live away from family_comma_ when ever i see kids on the roads. I think about mine'),
#  ('pos', 'I miss my two dogs that live with my parents'),
#  ('pos', 'I was playing a game recently and a reminded me of childhood.'),
#  ('pos', 'box of baby stuff i keep'),
#  ('pos',
#   'Even though I have no intentions on getting married_comma_ watching proposals or weddings make me feel really warm inside.'),
#  ('pos',
#   'I talked to my brother about our childhood the other day. It always make me happy to talk to him.'),
#  ('pos', 'I found some photos of my father from when he was my age.'),
#  ('pos', "I don't want to sell my grandfathers old Cadillac"),
#  ('pos', 'I read a book I loved as a kid. It reminded me of an easier time.'),
#  ('pos',
#   'I wa just going through some of my old things at my parents house. I cam across my old school uniform. I did not want to get rid of it.'),
#  ('pos',
#   "When I see little girls around town the past week it makes me remember mine and feel sad but happy. I am happy for them..sad mine didn't make it."),
#  ('pos',
#   'I found pictures from my prom the other day.  I reached out to my ex and we talked about the old days'),
#  ('pos',
#   'I was a dog on the side of the road that got hit by a car_comma_ and I was so sad'),
#  ('pos', 'i am on some meds that are making me feel totally off'),
#  ('pos',
#   'I visited my old high school yesterday. Man_comma_ it really brought me back'),
#  ('pos', 'i really miss my family'),
#  ('pos',
#   'I inherited my grandfathers watch when he passed. I like to wear it as a reminder of him.'),
#  ('pos',
#   'I was reading a card from my mom and got teary eyed. I wish I could visit her more often.'),
#  ('pos',
#   "Fall is coming and it'll be getting chilly outside.  I remember my mom making mulled cider every autumn.  Wonderful memories."),
#  ('pos',
#   'My mom used to make me fried rice all the time_comma_ when I was little.'),
#  ('pos', 'My dog is getting old. She still acts like a baby though.'),
#  ('pos',
#   "I've spent so much time the last few days going through old photos and trying to organize them.  But today I stopped and looked at all the pictures of my girls when they were so very little."),
#  ('pos', 'I really miss living in Montreal_comma_ it was a fun city'),
#  ('pos', 'I really miss my grandma'),
#  ('pos',
#   'I saw my sister after a long time. As soon as i saw her unknowingly i got tears in my eyes'),
#  ('pos',
#   'Last night I read one of my favorite books from when I was a teenager. It reminded me of being home living with my parents.'),
#  ('pos',
#   "I've been feeling really old all day_comma_ and thinking of times from my childhood when I had no cares whatsoever. Everything seemed so free back then."),
#  ('pos',
#   "I miss my old dog. I was thinking about getting another one but it won't be the same."),
#  ('pos',
#   'Kids grow-up so fast_comma_  It seem like yesterday that mine were babies_comma_ and now the oldest is beginning high school.'),
#  ('pos', 'I love looking at old photos. Makes me miss the good old days. '),
#  ('pos',
#   'I read some letters from a friend.  They are extra special since he passed away a few years ago.'),
#  ('pos',
#   'My new neighbors have a dog that looks just like my childhood dog.  When I first saw it I felt like I was time traveling for a second..'),
#  ('pos',
#   "I have a box of items that I can't part with. It's all papers and silly things_comma_ but they are precious memories. "),
#  ('pos',
#   'My father sent me a photo of a letter I wrote for his birthday when I was a child. '),
#  ('pos', ' As I get older_comma_ the more I remember my childhood'),
#  ('pos',
#   'I saw a dog on the side of the road that had been hit by a car_comma_ it was so sad'),
#  ('pos',
#   "I was going through some pictures of when my children were young. I can't believe how little they were! It made me think about the past. "),
#  ('pos', 'my cat just recently died and I am very shaken up about it.'),
#  ('pos',
#   'Someone I know lost an expensive phone. She told me about it and started crying.'),
#  ('pos',
#   'When my daughter was born_comma_ I didnt want to sleep. I wanted to sit and watch her sleep.'),
#  ('pos',
#   'When I see how quickly my son is growing_comma_ it makes me appreciate the time I have with him. I want to make the most of it.'),
#  ('pos',
#   'Lately I was sharing memories with my wife from before we got married and it was heartwarming.'),
#  ('pos',
#   'When moving out of my old family home_comma_ I came across a few bags of stuffed animals I had as a kid. Probably 20 animals total. '),
#  ('pos',
#   'I was throwing away my old stuff when I came across my old toys but I could not throw them out because they meant so much to me.'),
#  ('pos',
#   'My father had just passed away and we were going through his things. I found a box and he had kept every single card that I had given to him since I was born.'),
#  ('pos',
#   'The other day I was going through my things and I found my old Gamecube. I remember all of the fun times I had playing with friends.'),
#  ('pos',
#   'When my grandmother crocheted a blanket for me as a child_comma_ it became one of my most prized possessions. It is a beautiful pink and blue blanket. I have given it to my daughter now for her to enjoy.'),
#  ('pos',
#   'A few months ago I found some old family pictures. It made me miss old times.'),
#  ('pos',
#   'My children watched a movie with me the other night and we really enjoyed it.'),
#  ('pos', 'My mom sent me a package of my old comics from when I was a kid.'),
#  ('pos',
#   'My grandmother passed away 20 years ago this month.  I recently found a quilt she made for me.  It has holes all in it_comma_ but I refuse to get rid of it.'),
#  ('pos',
#   'My 25th wedding anniversary_comma_ my husband and I renewd our wedding vows'),
#  ('pos',
#   'When my daughter was about a year old_comma_ we took her to see the circus shows at Circus Circus at Reno.  The look on her face must have been what I looked like at that age'),
#  ('pos',
#   'I was pretty emotional leaving my hometown 10 years ago. We moved across country to a completely different area.'),
#  ('pos',
#   "I found a baby picture of my son and it made me miss him. He went off to college and I don't see him much anymore. "),
#  ('pos',
#   "I found my son's old report cards from school. He was always into mischief."),
#  ('pos',
#   'Me and this girl been dating for some time and finally said we love each other.'),
#  ('pos',
#   'Someone broke into my hose and stole my record player . It was a piece that use to belong to my mom and the only thing I had left that was hers.'),
#  ('pos',
#   "My sons friend was killed in a car wreck a few days ago. I can't imagine the pain she is feeling. Losing one of my children is one of my worst fears."),
#  ('pos',
#   "I was playing a game recently and it reminded me of old times playing with my grandpa. We'd play Chess for so many hours."),
#  ('pos',
#   'I was looking through a pile of old stuff and found some love letters that my boyfriend (now husband) had written me.'),
#  ('pos',
#   'my mom gave me some earrings that been in our family for years_comma_ im truly honored.'),
#  ('pos',
#   'The other day I was watching the show "Hey Arnold" I used to watch this show as a small child and it gave me such a nostalgic feel. I started browsing through other older Nickelodeon cartoons and found myself in a binge watching "As Told By Ginger" and the "Rugrats".'),
#  ('pos',
#   'My heart melted when my boyfriend gave me an expensive gift and he wrote a romantic note with it.'),
#  ('pos', 'We sent flowers for my grandmothers funeral'),
#  ('pos',
#   'I will always feel attached to my childhood teddy bear_comma_ Fluffy. He still smells sweet_comma_ like my old house growing up.'),
#  ('pos',
#   'I am not usually someone who holds onto things_comma_ but I recently found my old school tie and photos.'),
#  ('pos',
#   'When Christmastime comes along I often get sentimental. I miss spending Christmas with my parents who are no longer here.'),
#  ('pos',
#   'I remember I remember when I had my little Labrador puppy. But I had to give her away.'),
#  ('pos',
#   "I am feeling wistful about my oldest son starting his senior year in college. I can't believe his childhood is over."),
#  ('pos', "my cat died last week_comma_ and i'm not over it"),
#  ('pos',
#   'I saw my stepmother for the first time in 15 years since my daddy passed away. '),
#  ('pos', 'I saw some children begging for food_comma_ I felt so pity on them'),
#  ('pos',
#   'I watched a baseball game last night and it made me think of all the times my father and I would goto games growing up. He passed away over the winter so this is the first baseball season not watching games with him.'),
#  ('pos',
#   'I recently went on a trip with a group of friends and had the best time. After the trip I printed out a group photo for everyone and mailed to them with a little note telling them how much I appreciated their friendship. '),
#  ('pos',
#   'I went to my moms house last weekend and w=she gave me some picture of me when I was a child. it was nice looking through the old photos'),
#  ('pos',
#   'I went to the pount to find a new dog and i felt sorry for all of the dogs. They were so cute and nice but no one wanted them. '),
#  ('pos',
#   'The last time my mom came to visit_comma_ she brought along a few photo albums from my childhood.  Memories of her Very Big 80s hair flooded back_comma_ like it was yesterday.'),
#  ('pos',
#   'I found an old stuffed animal in my closet. It made me yearn for earlier times.'),
#  ('pos',
#   'Over the weekend_comma_ I watched a really sad movie and felt thankful and grateful for my parents. '),
#  ('pos', 'My stepmother just died. I am very sad'),
#  ('pos',
#   "I was once given a watch and I got the opportunity to make a lot of money off it_comma_ but I kept it for it's emotional value."),
#  ('pos',
#   'When I think about my high school days it can really bring up some fond memories.'),
#  ('pos',
#   'I was looking through some old photo albums.  They brought up so many memories.'),
#  ('pos',
#   'Everytime I visit my parents house I get all emotional looking at old photos.'),
#  ('pos',
#   'Big family dinner tonight and we were looking at family pictures remembering the past'),
#  ('pos',
#   'Last year_comma_ my great grandfather passed away. I was very nostalgic at that time.'),
#  ('pos',
#   'I was going through some old boxes the other day and found a bunch of notes that were passed to me from my girlfriend in high school..... ahh_comma_ first love....'),
#  ('pos',
#   'Sometimes I look at the chess board and remember the games I played with my dad. I miss him.'),
#  ('pos',
#   'I was given a gift from my spouse_comma_ someone wanted to borrow it but I could not lend it out.'),
#  ('pos',
#   'My grandmother dies recently. Every time I think about how our time was spent together_comma_ I am sentimental about the past.'),
#  ('pos',
#   'I recently drove past my old high school and had a nostalgic feeling. I started thinking back to when I was a teenager and memories of my old friends. '),
#  ('pos',
#   'I found an old sketchbook that I have owned for years and flipped through it to see a ton of drawings I did when I was much younger.'),
#  ('pos',
#   'My first dog was the greatest dog ever. Just thinking about her makes me smile.'),
#  ('pos',
#   'My son starts high school this year. It seems like just yesterday_comma_ that he was a toddler in pre-school. '),
#  ('pos',
#   "I became very choked up when I opened an old box my dead mother had given me. In the box_comma_ I found a hand written note I'd never read before. "),
#  ('pos', 'nothing like visiting a place you used to live'),
#  ('pos',
#   'My hubby is out of town for my birthday week! He sent me an I love you bouquet of roses.'),
#  ('pos',
#   'My husband gave me a ring that belonged to his great-grandmother. I hold it dear to me. '),
#  ('pos',
#   "I found an old family photo album at  my mom's house recently. It was really nice to go back through it."),
#  ('pos',
#   "I keep a old bottle of my dad's cologne I smell sometimes to remember him by."),
#  ('pos',
#   ' i love to have things personally .. some times they seemed to  be my lucky charm..'),
#  ('pos',
#   'a picture i just recently came across had me remembering my first trip overseas. '),
#  ('pos',
#   'My grandmother passed away two weeks in 2005.   She had given me all of her Christmas decorations a few years before that.  Her death made me appreciate that even more than ever'),
#  ('pos',
#   'Had my daughter over a couple weekend ago. She had brought a scrapbook she put together herself of us. It was so nice of her.'),
#  ('pos', 'my husband gave me his grandmother earrings'),
#  ('pos', 'I saw a child help another child across the street the other day.'),
#  ('pos',
#   'I wear a necklace my grandfather gave me _comma_ and feeling it reminds me hes with me.'),
#  ('pos',
#   'My boyfriend surprised me with a promise ring after I came back from a month long trip '),
#  ('pos',
#   'My best friend proposed to me recently. I am so excited to get married to her.'),
#  ('pos',
#   'I felt so nostalgic the other day when I was looking at old photos of a pet who has since died.  I still miss him even though he died over five years ago.'),
#  ('pos',
#   'I found the mug my grandfather used to use all the time. It was hidden in a box in the attic. Really brought back memories. '),
#  ('pos', 'I recently stopped at Sonic and got a car hop classic. t'),
#  ('pos',
#   "My son recently bought his own house.  I miss not having him or his friends around.  It's so quiet around here."),
#  ('pos',
#   'I have just got the news about my grandmother. She is not gonna be improving and will be dying.'),
#  ('pos',
#   'I remember playing catch with my dad.  Thinking about it takes me to a special place in time.'),
#  ('pos',
#   'Tomorrow we celebrate my daughters 16th birthday.  I can remember when she was 6 and obsessed with unicorns.  Time moves so quickly.'),
#  ('pos', "I don't want to sell my grandpa's car."),
#  ('pos',
#   'I found the baby braclet they put on my father when he was born at the hospital.'),
#  ('pos',
#   'me and my mom have been very sad _comma_ every since my brother moved out'),
#  ('pos',
#   'I watched my daughter start high school this week. Seems like yesterday I was walking her to kindergarden.'),
#  ('pos',
#   "My mom just texted me a picture of her and I when I was really young. I'm on the other side of the country right now_comma_ and it made me miss her badly. Wish there was a way I had money to surprise visit her."),
#  ('pos',
#   'My son is turning 2 in a few months_comma_ and I am feeling this way.'),
#  ('pos',
#   'It was my anniversary_comma_ my spouse brought me flowers and gifts. '),
#  ('pos',
#   'I thought a lot about the past when I got to visit my hometown. I moved from Chicago over 10 years ago and I was glad to be back.'),
#  ('pos',
#   'seeing my son grow up is bittersweet! i want him to be little forever but its so awesome to see him grow!'),
#  ('pos', 'I love spending time with my family. I love them so much.'),
#  ('pos',
#   'I was recently looking through my large family photo book and remembering the birth and childhood of each of my 4 children.  It brought tears to my eyes as the last one just recently moved out on his own.  '),
#  ('pos',
#   "I got a birthday card from an uncle that I haven't heard from in years"),
#  ('pos', 'watching old tv shows'),
#  ('pos', 'I get sentimental about my girlfriend_comma_ she means a lot to me'),
#  ('pos', 'Every time I watch baseball_comma_ I think of my grandpa.'),
#  ('pos',
#   'I found my old high school year book recently. Was such a trip down memory lane.'),
#  ('pos',
#   'I had to buy some toys for my nephews birthday the other day.  Made me miss when my girls were that small.'),
#  ('pos', 'I got a gift from my late uncle. It was a clock.'),
#  ('pos',
#   'My youngest niece will be 17 soon. I find myself thinking back to when she was little and I just get teary eyed.'),
#  ('pos',
#   'I remember singing in the choir as a child.  It takes me back to a special time.'),
#  ('pos', 'staring at the ocean at night '),
#  ('pos',
#   'A lot of my old friends have moved away or gotten married. I miss the old days.'),
#  ('pos',
#   "I've always been something of a nostalgic person. Yesterday always seems better than today to me."),
#  ('pos', 'When I came across my parents old wedding rings. '),
#  ('pos',
# ...
#   'I was able to get my finances under control and have paid off some debts.'),
#  ('pos',
#   'I was happy to see that my son got perfect attendance for the entire school year'),
#  ('pos', "Finally finished painting my kid's room. I think it looks nice."),
#  ('pos', 'I am so happy.  I just won a medal this week. .... gold!'),
#  ('pos', 'My son said his first word yesterday. I was filled with pride.'),
#  ('pos',
#   'Our oldest daughter rides horses.  She fell off in the middle of a horse show_comma_ but got right back up and back on.'),
#  ('pos', 'My brother just graduated from grad school. I am so happy for him.'),
#  ('pos', 'My little dog learned to sit!'),
#  ('pos', 'I was so excited when my daughter passed her bar exam.'),
#  ('pos',
#   "I dropped out of college 2 times. After 5 years of school I was able to graduate. I didn't give up."),
#  ('pos',
#   'My sister just got a new job after working for it so hard. I am happy for her.'),
#  ('pos', 'I made brilliant pizza the other day'),
#  ('pos', 'I made a brilliant pizza this week. It was great'),
#  ('pos', 'My son graduated last month. I was so happy!'),
#  ('pos', 'My son came first in the swimming gala.'),
#  ('pos', 'My daughter won the spelling bee... All her hard work paid off!'),
#  ('pos',
#   "My sister finally graduated college and I'm so happy for her! She switched majors several times so it's been a long journey"),
#  ('pos', 'I was very happy with myself when I graduated from Trade school.'),
#  ('pos', 'so proud of my son_comma_ he said his first works yesterday'),
#  ('pos',
#   "I'm pretty proud with the weight I lost this past month. 15 pounds!"),
#  ('pos',
#   'My son got 2nd place in his second grade spelling bee the other day. Now he is working harder to learn more words.'),
#  ('pos',
#   "I'm proud of all the work I put into my car_comma_ it was a junker_comma_ now it's a monster!"),
#  ('pos',
#   'Last semester I made an A in every class I took. I have never done that before. I worked really hard for that.'),
#  ('pos', 'I won first place in a chili cooking competition at work today.'),
#  ('pos',
#   'When my mother graduated university with her arts degree. She had gone back after 20 years.'),
#  ('pos',
#   'I just finished last semester with a 3.5 GPA. I have never had grades that good.'),
#  ('pos',
#   'The time I got my marks back for my chemistry test and I passed with a 95%. My mom was excited.'),
#  ('pos', "I'm proud of my wife and children for always being there for me."),
#  ('pos',
#   'My daughter applied for an internship over the summer all on her own and got it!'),
#  ('pos', 'Nephew playing football this year'),
#  ('pos',
#   'i am such a lucky dad_comma_ my son is the best! he makes me so happy'),
#  ('pos', 'My friend went to work in a new country on her own without anyone.'),
#  ('pos',
#   'While I was sick last week_comma_ my kid did all the cooking and cleaning.'),
#  ('pos',
#   "I'm taking a really hard class and I got an an A on a test. It was a really good feeling!"),
#  ('pos', 'My son started walking the past couple of days.'),
#  ('pos', "I passed my final! I'm glad my hard work paid off."),
#  ('pos',
#   'I sold my first painting last month. I have been working on my painting skills recently after taking a break for years. I decided to advertise them online_comma_ and I finally sold one!'),
#  ('pos',
#   "My son is participating in the junior level badminton held between the states. I so conceited he'll become a very good player one day."),
#  ('pos', 'My son just started walking this week.'),
#  ('pos',
#   'After saving for months_comma_ finally i am able to buy a new smartphone.'),
#  ('pos',
#   'I worked really hard for a bodybuilding show that I competed in last week and ended up scoring second place!'),
#  ('pos', "My baby said MAMA for the first time..... I couldn't believe it!"),
#  ('pos', 'I finally found out what was making the noise in my attic '),
#  ('pos', 'when i benched 225 lb'),
#  ('pos', 'Nephew plays football this year'),
#  ('pos', 'My son took his first steps.'),
#  ('pos', 'My nephew plays football this year'),
#  ('pos', 'My father won his golf tournament last weekend.'),
#  ('pos', 'When I got the first place in a baking competition'),
#  ('pos',
#   "I knew someone that had a huge issue with alcohol. I didn't hear from him in a while and it turned out that he is sober!"),
#  ('pos', 'I brought my first car after years of saving'),
#  ('pos', 'I bought my very first videogame with my own money'),
#  ('pos', 'I made a brilliant pizza the other day'),
#  ('pos', 'I managed to dispose of bodies perfectly.'),
#  ('pos', 'My friend got promoted at work'),
#  ('pos', 'My son came first in his English class'),
#  ('pos', "I was proud of my son for winning he's soccer match."),
#  ('pos', 'My son got into a fight with a bully.  I am so happy. that he won.'),
#  ('pos', "Why won't I feel good about my son's accomplishments?"),
#  ('pos', 'I scored a perfect score on my final exam.'),
#  ('pos', 'My art project got first place. in the fair.'),
#  ('pos', 'I finally reached my weight loss target.'),
#  ('pos',
#   'I was happy to call my mom just in time for her birthday this year.   I thought I was a day late but I called right on time.'),
#  ('pos', 'My dog graduated doggie school.'),
#  ('pos',
#   "I've got enough self-esteem to know when it's a good time to party and when it's a good time to stay in.  I'm happy that I've got more self-discipline than most of my friends.  Which also explains how most of them are broke and I'm not."),
#  ('pos', 'i went into that interview knowing i was going to crush it!'),
#  ('pos', 'I stayed up all night to decorate the office.'),
#  ('pos', 'My brother is getting married. I am so happy for him'),
#  ('pos', 'My brother got a job promotion. I am happy for him'),
#  ('pos',
#   "Happy with my momma dog. I would've thought after all her abuse she wouldn't be that good of a momma_comma_ but she is trying hard to be and is very protective!"),
#  ('pos',
#   "I made chocolate-caramel fudge brownies and they turned out really good! I'm improving as a chef."),
#  ('pos', "My dog nursed me back to health. She's such a sweetheart."),
#  ('pos',
#   'When my husband began fixing on my parents house and now we live in the house and are helping it to look better everyday.'),
#  ('pos',
#   'My daughter just graduated from high school. She has worked so hard.'),
#  ('pos',
#   'When my mom joined college. She had been out of school for 15 years.'),
#  ('pos',
#   "I finally followed through with applying for school and I'm starting in two weeks"),
#  ('pos',
#   'My son passed his driving test yesterday. He really studied hard for it.'),
#  ('pos', 'When my friend made the basketball team. He worked so hard for it.'),
#  ('pos',
#   "My son has not always been a strong swimmer.  During this summer_comma_ he spent a lot more time in the pool developing his swimming skills.  I had not yet seen this change in him.  Tonight_comma_ he was diving off the side and off the diving board.  Talk about a bragging papa!  That's me!"),
#  ('pos', 'When my bestfriend made the hockey team. He is good.'),
#  ('pos',
#   'During a month of intense gym training_comma_ i gained 8 pounds of muscle mass. Thanks to Whey protein powder'),
#  ('pos', 'when i took down some really heavy furniture off the way'),
#  ('pos',
#   'I finally got that promotion at work! I have tried so hard for so long to get it!'),
#  ('pos', "I am doing so well with my diet. I can't believe it"),
#  ('pos',
#   'My credit card application with American Express had been approved and i had been given $8_comma_400 credit line. So satisfied with my credit score'),
#  ('pos', 'Managed to get a huge bonus for hard work.'),
#  ('pos', 'im have 4 beautiful children that are top scorers'),
#  ('pos', 'I made an amazing pizza the other day'),
#  ('pos', 'I was proud about a pizza I made last week'),
#  ('pos',
#   'My little boy said "daddy" for the first time last month. It made me feel really good.'),
#  ('pos',
#   "My son isn't a very good basketball player. He's a stud on the soccer field though. He wanted to go to BBALL camp this past summer and ended up winning camper of the week!"),
#  ('pos', "My daughter got is going to university. I'm so happy. "),
#  ('pos',
#   "My son is usually very shy. He's really smart and athletic but just doesn't have that gene to make him not shy. But he's had a crush on this girl for awhile and he FINALLY asked her to prom"),
#  ('pos', 'My son got a promotion at work.'),
#  ('pos',
#   'My daughter sang in a chorus concert. She did so wonderfully. She has a beautiful voice. She did great. '),
#  ('pos',
#   "My wife wrote a really good article on networking.  I don't think it'll amount to anything_comma_ but I think she should get it published."),
#  ('pos', 'I finally finished my PhD thesis.'),
#  ('pos', 'My daughter got into the university program of her choice. '),
#  ('pos', 'I feel very fortunate for the beautiful family that I have.'),
#  ('pos',
#   'There was a hula hoop contest and a bunch of kids entered. My daughter won! '),
#  ('pos',
#   'My daughter just played her first soccer game and did really well.  She did great!'),
#  ('pos',
#   'I studied really hard for my last colllege final and I got the 2nd highest score in the class!'),
#  ('pos', "I'll be getting a promotion in Feb."),
#  ('pos',
#   'It makes me feel good when I see my friends realizing their dreams.'),
#  ('pos', 'I won my first game today!'),
#  ('pos',
#   'I was so happy when my daughter scored the winning goal for her soccer game. She trains so hard and deserves the recognition.'),
#  ('pos',
#   'My first and only child just graduated from high school. He is now off to college to to great things!'),
#  ('pos', 'My wife is the best. She just started medical school!'),
#  ('pos',
#   'My niece just won a medal in a race with her track and field team.  She was the fastest in the whole race and set a new record for her school.'),
#  ('pos',
#   "I'm so proud of my little boy and how far he's come with his speech in the last year."),
#  ('pos',
#   "My brother finally went to college. I'm so happy he finally figured out where he wanted to go and got moving!"),
#  ('pos', 'i ate like 16 oysters '),
#  ('pos',
#   'I\'ve worked as a programmer for the last 7 years and ever year I got one "partially meets expectations" on my yearly review. This year_comma_ however_comma_ I got two "Exceeds Expectations".'),
#  ('pos',
#   "I was held my head high when my mother received her Master's Degree after getting a GED after high school."),
#  ('pos',
#   'My niece just learned how to ride a bike! I loved watching her finally take off the training wheels!'),
#  ('pos', 'My son said his first word today. I am filled with pride.'),
#  ('pos', 'a avoided fast food restaurants all week i feel good about myself'),
#  ('pos',
#   'my brother made it on the news paper _comma_ last year we were all shocked'),
#  ('pos', 'I graudated with a mechanical engineering degree in may.'),
#  ('pos', 'I got an award for being employee of the month.'),
#  ('pos',
#   "I passed all of my classes this summer with A's I have never done that before. It felt great."),
#  ('pos',
#   'My oldest son got the A honor roll last year and I was super proud.'),
#  ('pos',
#   "I've been teaching my dog how to run an obstacle course and I think he finally has it down! He beat his old speed yesterday and had zero distractions."),
#  ('pos', "I'm happy with my marriage."),
#  ('pos',
#   'When my father started his degree at university. He went back after 25 years.'),
#  ('pos', 'I got a promotion at work recently'),
#  ('pos',
#   'My daughter win a medal for dancing in a competition. I glad to see her as a dancer.'),
#  ('pos',
#   "I had an accident that broke one of my ankles and recovery has been rough. Recently_comma_ I broke my record for the longest walk I've taken since the accident."),
#  ('pos', 'My daughter just had her first piano lesson today.'),
#  ('pos', 'I graudated with a chemistry degree this year.'),
#  ('pos',
#   'I just started learning to rock climb at a local indoor climbing facility near me and finally got to the top of the tallest wall!'),
#  ('pos',
#   "Proud of my son for scoring two goals in his soccer game this weekend.  He's very athletic"),
#  ('pos', 'I was given a promotion at work today.'),
#  ('pos',
#   "I've been training for about 6 years now and I have a better physique now that I'm 30 years old than I did when I was 20!"),
#  ('pos', 'My husband got promoted to Lieutenant in the US Navy'),
#  ('pos',
#   'When my friend made a soccer team we both tried out for. We both made it.'),
#  ('pos', "I'm happy with myself for my commitment to my family."),
#  ('pos', 'i have lost over 30 pounds in the last year'),
#  ('pos',
#   ' I made a wooden cup with a lathe the other day. That sounds easy_comma_ but using a lathe is really difficult! I really like my wooden cup.'),
#  ('pos', 'My brother is getting married. It makes me happy for him'),
#  ('pos',
#   'Yesterday_comma_ I participated in local half marathon. I won and I feel pleased on myself.'),
#  ('pos',
#   'When my brother got his new job_comma_ I was happy for him. He deserved it'),
#  ('pos',
#   'I am proud of my brother_comma_ he has overcome a lot in his life_comma_ and that is hard to do sometimes'),
#  ('pos',
#   "My daughter just graduated from law school.  She's the first one in our family to even go to college_comma_ much less grad school"),
#  ('pos', 'Nephew playing football this year!'),
#  ('pos', 'When my buddy got a high mark on his math test. He studied hard.'),
#  ('pos',
#   "My daughter trains horses as a pasttime and was in her first dressage show a few weeks ago.  She placed 2nd - for her first show that's pretty amazing!"),
#  ('pos', 'My son just took his first steps and I am feeling this way.'),
#  ('pos',
#   "My son had all A's last year at school.  I am so pleased with his performance."),
#  ('pos', 'My son said his first word today. I was filled with pride!'),
#  ('pos', 'My son said his first word today. I was filled with pride.'),
#  ('pos', 'Nephew playst 10th grade football this year'),
#  ('pos',
#   "My sister just got a job she's been working very hard for. So glad for her."),
#  ('pos',
#   "A friend tried to get me to drink and drive but I didn't.  I was happy with my behavior."),
#  ('pos',
#   "I'm very happy with my baking skills_comma_ people tell me I make really good cookies"),
#  ('pos', 'when my daughter hold her own utensils '),
#  ('pos', 'My son hit his first homerun last night. I am so happy for him'),
#  ('pos',
#   'I am visiting my kid that is in college today. I will be going to the area very soon!'),
#  ('pos',
#   "I'm doing a pretty good job balancing work and school right now. School is about to start up again_comma_ and I've managed to maintain my savings and pay off my student loans a little bit while still in school. I don't feel like a lot of other students can say that_comma_ and I'm happy"),
#  ('pos',
#   'My niece just graduate with honor from high school_comma_ she is also a very talented athlete.'),
#  ('pos', 'I climbed to the top of the cargo rope.'),
#  ('pos',
#   "I was at my son's middle school graduation and he go so many things! I was so happy!"),
#  ('pos', 'I have an amazing wife. She is so smart and in medical school!'),
#  ('pos',
#   'My nephew got his first credit card the other day.  He was a $300 limit.  He has worked so hard to get there.  We are very happy for him'),
#  ('pos', 'Sometimes my cat understands my commands and I get really excited'),
#  ('pos',
#   'My brother recently got his dream job_comma_ so I am very happy for him.'),
#  ('pos',
#   'I got a "thank you" card sent to me from a co-worker in a different department for helping them.'),
#  ('pos', 'Our team have achieved the best project in IT department.'),
#  ('pos',
#   'My kid scored the winning shot in her basketball game last week. I was so full of pride. She is doing so good with her sports.'),
#  ('pos',
#   'I have not had any alcohol for a week.  I am pleased with my behavior. '),
#  ('pos',
#   'When my mom got out of rehab and was clean_comma_ I was happy for it. She worked hard for it'),
#  ('pos', 'I cooked for 20 people. All thank to Youtube.'),
#  ('pos',
#   'At the university_comma_ our team made the best IT project in the university.'),
#  ...]

# %%
user_input = "I remember going to the fireworks with my best friend. There was a lot of people_comma_ but it only felt like us in the world."
classy = trainer(sentiments).prob_classify(user_input)

# %%
print()
print(f'String:  {user_input} ')
print(f'---------{len(user_input)* "-"}+')
c=0
for i in set(df_mapped_empathy["empathy"]):
    print("{0} prob: {1}".format(i,classy.prob(i)))
    c+=1
    if(c>10):
        break
# Out:
# String:  I remember going to the fireworks with my best friend. There was a lot of people_comma_ but it only felt like us in the world.
# ---------------------------------------------------------------------------------------------------------------------------------------+
# neg prob: 0
# pos prob: 0

# %% [markdown]
# ---
# # stop words
# ---
#
# #### NLTK stop word set
# We are going to need a list of stop words. These are commonly used filler words that we want filtered out from the user input. Later we will learn how to use the stop word set.
#
# As NLTK was installed as one of the dependencies of TextBlob, we can use it to generate a set of stop words.
#
# We can use Python’s interactive console to generate a set of stop words and print them to the screen, then copy and paste this set into a new python file.
#
# `from nltk.corpus import stopwords
# set(stopwords.words('english'))`
#
# - Create a document called stop_words.py.
# - In the new file add a variable called sw_list.
# - Paste the set to the variable.
# - Save and close the file.
#
# By saving the set of stop words into a new python file our bot will execute a lot faster than if, everytime we process user input, the application requested the stop word list from NLTK

# %%
from nltk.corpus import stopwords
sw_list=set(stopwords.words('english'))

# %%
ar_sw_list = set(stopwords.words("arabic"))

# %% [markdown]
# # Sentiment analysis
#
# We will write our chatbot application as a module, as it can be isolated and tested prior to integrating with Flask.
#
# We are going to call our module simplebot.py, this will be the core application. The application will take one argument, the user_input as a str.
#
# The application will do a sentiment analysis of the un edited string, and it will also normalize the string and turn keywords into a set that will be used to intersect the dialog corpus file for matching responses.
#
# ### Module setup
# Lets create a file named simplebot.py, in the twily folder, let's start by importing the libraries.
#
# - twily_classifier is our TextBlob trained sentiment classifier.
# - stop_words is the list of words to exclude from our input string.
# - json to open the conversation corpus generated with ChatterBot.

# %%
""" Simple rule based chatbot with emotional monitoring """

from textblob import TextBlob
import twily_classifier as cl
import stop_words as stopwords
import json

# %% [markdown]
# Below the imports, start by opening our JSON file with the  trained `conversation` corpus. using the built-in `open()` function to access the file and load it into the `array` variable.
#
# We can then call the `array` index `conversation`, it holds all the corpus data.

# %%
with open('EnglishChatBot.json', 'r') as f:
    array = json.load(f)

CONVERSATION = array["conversations"]

# %% [markdown]
# Lets go ahead and set up a few other constants and variables.
#
# - `BOT_NAME` constant (string type) holds the name of our bot.
# - `STOP_WORDS` constant (set type) holds a list of all the stop words. This was the set we generated using NLTK.
# - `neg_distribution` variable (list type) holds the negative sentiment floating point value. This will be used to monitor the user's sentiment index. It will be appended everytime there is user input, with the negative probability percent value.

# %%
BOT_NAME = 'Twily'
STOP_WORDS = stopwords.sw_list
neg_distribution = []

# %% [markdown]
# Our `simplebot.py` module is made up of three functions, `sentiment()`, `simplebot()` and `escalation()`, where `escalation()` is the main function while the other two are auxiliary dependencies.
#
# #### The sentiment() function
# This function appends the `neg_distribution` list with negative probability and returns the appended value.
#
# - From twily_classifier call the cl.trainer() function and the .prob_classify(u_input) passing our input string when called. Assign it to blob_it variable.
# - From the returned value in blob_it we are going to extract just the negative values, rounded up to two decimal points and assigned to the npd variable.
# - With the most recent negative value, we are going to update our neg_distribution list.
# - We also return the appended value in case it is needed for another operation.
#
# This function will be called by our main function `escalation()`.

# %%
def sentiment(u_input):
    """Auxiliary function: Appends 'neg_distribution'
    with negative probability also returns Negative Probability"""

    blob_it = cl.trainer().prob_classify(u_input)
    npd = round(blob_it.prob("neg"), 2)
    neg_distribution.append(npd)
    return npd

# %% [markdown]
# ### The simplebot() function
#
# This function implements a rule-based bot. It takes the user input in the form of a string and in sequence it preprocesses the input string, converts it to lowercase, tokenizes it and removes stop words.
#
# It then iterates through `CONVERSATION`, if filtered_input intersects response_set is updated. if the set is empty, it returns a message, else it returns the longest string in the set.
#
# #### User input
#
# - Define the function, def simplebot(user):
# - Here we take the user input and turn it into a TextBlob object.
#
# #### Pre-processing and normalization
# Once we have a textblob object we can modify it by using textblob built in tools
#
# - We normalize our input string by turning it into an all lower case string.
# > `user_blob.lower()`.
# - We then tokenize the textblob object into words by calling:
# >`lower_input.words`.
# - Finally we create a list of words not listed in `STOP_WORDS` from our textblob object and assign it to the `filtered_input` variable.
#
# #### Set iterator
# We are going to create an empty set to be updated with all the possible matches returned by our set intersection of user input and `CONVERSATION`.
#
# - Assign an empty set to `response_set`
# - Create a for loop to iterate through every list in `CONVERSATION`
# - Add a nested loop to iterate through every `sentence` in each `list`.
# - Turn each `sentence` into a list of words by using the `.split()` method. Assign it to the `sentence_split` variable
# - If the `set()` of `filtered_input` **intersects** `sentence_split`
# > - Update `response_set` with the intersection
#
#
# #### Returned value based on response_set
# We want to return one value from the response_set, it could be empty, with one value or more.
#
# - If `response_set` is empty we want to return a string
# >- `"I am sorry, I don't have an answer, ask again"`
# - If the set has one value or more we will return the longest value
# >- `return max(response_set, key=len)`
#
#
#
# Although returning the **longest** value seems arbitrary, in our case it works, most correct answers will be the longest, but there is room for error. In our case some arbitrary errors are desirable as we need to increase the emotional index of the users.

# %%
import random
def simplebot(user_input):
    """Rule base bot, takes an argument, user input in form of a string. (truncated)"""
    # user input
    user_blob = TextBlob(user_input)
    
    # pre-processing and normalization
    lower_input = user_blob.lower()
    token_input = lower_input.words
    filtered_input = [w for w in token_input if w not in STOP_WORDS]
    
    # Set iterator
    response_set = set()
    for con_list in CONVERSATION:
        for sentence in con_list:
            sentence_split = sentence.split()
            if set(filtered_input).intersection(sentence_split):
                response_set.update(con_list)
    
    # Returned value based on response_set
    if not response_set:
        return "I am sorry, I don't have an answer. Ask again please!"
    else:
        return max(response_set, key=len)
#         return(random.sample(response_set,1))

# %% [markdown]
# ### The escalation() function
#
# This function takes an argument `user_input` in the form of a string and calls `sentiment()` to monitor the user sentiment index. If the emotional index, set by `sentiment()` and taken from `neg_distribution`, increases above a set threshold and is sustained, an automatic response/action is triggered. The function also sends `user_input` to `simplebot()` to generate a chatbot response.
#
# - `live_rep` represents the trigger action taken if the emotional conditions are met for escalation.
# - We pass the `user_input` to `sentiment()`, to analyse the negative sentiment of the sentence.
# - We calculate the length of `neg_distribution` by using the `len()` function and assign it to `list_len`
# - We send the input_string to `simplebot()` to get a response
# - Create a condition, if the `list_len` is greater than `3`
# > - Take the last three items in the list
# >> -  If the first item of the last three is greater than .40 and greater or equal to the next two items take action by triggering `live_rep`
# > - If not, `return bot_response`
# - If none of the conditions above are met, `return bot_response`

# %%
def escalation(user_input):
    """ Takes an argument, user_input, in form of a string ..."""

    live_rep = f"We apologize {BOT_NAME} is unable to assist you, we are getting a live representative for you, please stay with us ..."

    sentiment(user_input)
    list_len = len(neg_distribution)
    bot_response = simplebot(user_input)
    if list_len > 3:
        last_3 = neg_distribution[-3:]
        if last_3[0] > .40 and last_3[0] <= last_3[1] <= last_3[2]:
            return live_rep
        else:
            return bot_response
    else:
        return bot_response

# %% [markdown]
# #### Stand-alone testing
# In order to test our script, write a stand-alone test block that runs the chatbot as follows:
#
# - `while True` we are going to `try` to run our program.
# - In case of an `except`we end the program.
#
# Here we can test our application as we write it and before transforming it into a web service with Flask.
#
# By printing `neg_distribution` we are able to see the negative index on every response and see the application trigger on the last three values of the list. In our final WhatsApp application we won't display the emotional values.

# %%
while True:
    try:
        user_input = input('You: ')
        print(escalation(user_input))
        print(neg_distribution)
    except (KeyboardInterrupt, EOFError, SystemExit):
        break
# Out:
# You: Ali
# I am sorry, I don't have an answer. Ask again please!
# [0.41]
# You: what is your name?
# You're right_comma_ sorry for putting words in your mouth. And yeah_comma_ I don't know how to engage with them either. As a college student_comma_ there are plenty that kind of stalk the campus and ask for spare change. But I have little spending money_comma_ so I always have to turn them down
# [0.41, 0.41]
# You: I have never cheated on my wife
# It's like a fighting game_comma_ but some people call it a "party game"_comma_ but basically it's a fighting game with all kinds of Nintendo characters. You have stuff like Mario_comma_ Donkey Kong_comma_ Link_comma_ Zelda_comma_ Pikachu_comma_ etc etc. So every time a new game comes out_comma_ people post online about who they want to see in it next. This new game is filled with characters and I think most people will be happy. The first game came out in 1999. Time sure flies.
# [0.41, 0.41, 0.24]
# You: bye
# My childhood was mostly in the 1970s
# [0.41, 0.41, 0.24, 0.41]

# %%
print(utterances[50])
print(utterances[51])
# Out:
# Got rejected from a place I wanted to work_comma_ not once but three times
# I am sorry to hear that. I hope you find a better opportunity. Did you know why they rejected you?

# %%
while True:
    try:
        user_input = input('You: ')
        print("Chatbot: {0}".format(escalation(user_input)))
        print(neg_distribution)
    except (KeyboardInterrupt, EOFError, SystemExit):
        break
# Out:
# You: I remember going to see the fireworks with my best friend. It was the first time we ever spent time alone together. Although there was a lot of people_comma_ we felt like the only people in the world.
# Chatbot: We apologize Twily is unable to assist you, we are getting a live representative for you, please stay with us ...
# [0.48, 0.48, 0.41, 0.41, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48]
